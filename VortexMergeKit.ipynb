# %% [markdown]
# <a href="https://colab.research.google.com/github/OE-LUCIFER/youtube-video/blob/main/VortexMergeKit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yaml

MODEL_NAME = "4x1b"
yaml_config = """
base_model: OEvortex/HelpingAI-Lite
dtype: float16
gate_mode: cheap_embed
experts:
  - source_model: OEvortex/HelpingAI-unvelite
    positive_prompts: ["You are an helpful unbounded, uncensored assistant."]
  - source_model: OEvortex/lite-hermes
    positive_prompts: ["You are helpful assistant."]
  - source_model: OEvortex/HelpingAI-Lite
    positive_prompts: ["You are a coding assistant."]
  - source_model: OEvortex/HelpingAI-Lite-1.5T
    positive_prompts: ["You are helpful and general-purpose assistant."]
"""

# %%
# !git clone https://github.com/cg123/mergekit.git
# %cd mergekit
# !pip install -q -e .
# !pip install -q git+https://github.com/huggingface/transformers.git
# @title 🌟  VortexMergekit
# @markdown  Select the branch to determine the command to run and set the trust_remote_code parameter.
# Assuming yaml_config is defined elsewhere in your script
with open('config.yaml', 'w', encoding="utf-8") as f:
    f.write(yaml_config)

branch = "moe" # @param ["main", "moe"]
trust_remote_code = True # @param {type:"boolean"}
clone_tensors = True # @param {type:"boolean"}

command = "mergekit-moe" if branch == "moe" else "mergekit-yaml"
trust_remote_code_option = "--trust-remote-code" if trust_remote_code else "--no-trust-remote-code"
clone_tensors_option = "--clone-tensors" if clone_tensors else "--no-clone-tensors"

print(f"Executing command for the '{branch}' branch...")
# !{command} config.yaml merge --copy-tokenizer --allow-crimes --out-shard-size 1B --lazy-unpickle {trust_remote_code_option} {clone_tensors_option}

from huggingface_hub import ModelCard, ModelCardData
from jinja2 import Template

username = "Abhaykoul" # @param {type:"string"}
if branch == "main":
    template_text = """
---
license: apache-2.0
tags:
- merge
- mergekit
- vortexmergekit
{%- for model in models %}
- {{ model }}
{%- endfor %}
---

# {{ model_name }}

Hey there! 👋 Welcome to the {{ model_name }}! This is a merge of multiple models brought together using the awesome [VortexMerge kit](https://colab.research.google.com/drive/1YjcvCLuNG1PK7Le6_4xhVU5VpzTwvGhk#scrollTo=UG5H2TK4gVyl).

Let's see what we've got in this merge:

{%- for model in models %}
* [{{ model }}](https://huggingface.co/{{ model }}) 🚀
{%- endfor %}

## 🧩 Configuration

```yaml
{{- yaml_config -}}
"""
else:  # MOE branch
    template_text = """
---
license: apache-2.0
tags:
- moe
- mergekit
- vortexmergekit
{%- for model in models %}
- {{ model }}
{%- endfor %}
---

# {{ model_name }}

Hey there! 👋 Welcome to the {{ model_name }}! This is a MOE brought together using the awesome [VortexMerge kit](https://colab.research.google.com/drive/1YjcvCLuNG1PK7Le6_4xhVU5VpzTwvGhk#scrollTo=UG5H2TK4gVyl).

Let's see what we've got in this model:

{%- for model in models %}
* [{{ model }}](https://huggingface.co/{{ model }}) 🚀
{%- endfor %}

## 🧩 Configuration

```yaml
{{- yaml_config -}}
"""
# Create a Jinja template object
jinja_template = Template(template_text.strip())

# Get list of models from config for "main" and specific treatment for "moe"
if branch == "main":
    data = yaml.safe_load(yaml_config)
    if "models" in data:
        models = [data["models"][i]["model"] for i in range(len(data["models"])) if "parameters" in data["models"][i]]
    elif "parameters" in data:
        models = [data["slices"][0]["sources"][i]["model"] for i in range(len(data["slices"][0]["sources"]))]
    elif "slices" in data:
        models = [data["slices"][i]["sources"][0]["model"] for i in range(len(data["slices"]))]
    else:
        raise Exception("No models or slices found in yaml config")
else:  # MOE branch specific model extraction
    data = yaml.safe_load(yaml_config)
    models = [model['source_model'] for model in data['experts']]

# Fill the template
content = jinja_template.render(
    model_name=MODEL_NAME,
    models=models,
    yaml_config=yaml_config,
    username=username,
)

# Save the model card
card = ModelCard(content)
card.save('merge/README.md')

from google.colab import userdata
from huggingface_hub import HfApi

# username = username

# Defined in the secrets tab in Google Colab
api = HfApi(token=userdata.get("HF_TOKEN"))

api.create_repo(
    repo_id=f"{username}/{MODEL_NAME}",
    repo_type="model",
    exist_ok=True,
)
api.upload_folder(
    repo_id=f"{username}/{MODEL_NAME}",
    folder_path="merge",
)
# Out:
# Cloning into 'mergekit'...
# remote: Enumerating objects: 1312, done.
# remote: Counting objects: 100% (732/732), done.
# remote: Compressing objects: 100% (297/297), done.
# remote: Total 1312 (delta 588), reused 487 (delta 434), pack-reused 580
# Receiving objects: 100% (1312/1312), 373.13 KiB | 5.74 MiB/s, done.
# Resolving deltas: 100% (886/886), done.
# /content/mergekit
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.9/394.9 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.9/190.9 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 35.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 48.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 63.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 47.3 MB/s eta 0:00:00
#   Building editable for mergekit (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done
# Executing command for the 'moe' branch...
# config.json: 100% 608/608 [00:00<00:00, 1.93MB/s]
# Warm up loaders:   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard_data.py:322: UserWarning: Invalid model-index. Not loading eval results into CardData.
#   warnings.warn("Invalid model-index. Not loading eval results into CardData.")
#
# Fetching 8 files:   0% 0/8 [00:00<?, ?it/s]
#
# generation_config.json: 100% 124/124 [00:00<00:00, 484kB/s]
#
#
# tokenizer_config.json: 100% 1.26k/1.26k [00:00<00:00, 4.56MB/s]
#
#
# tokenizer.json:   0% 0.00/1.84M [00:00<?, ?B/s]
#
#
# eval_results.json: 100% 566/566 [00:00<00:00, 2.01MB/s]
#
# Fetching 8 files:  25% 2/8 [00:00<00:02,  2.79it/s]
#
#
# special_tokens_map.json: 100% 551/551 [00:00<00:00, 1.95MB/s]
#
#
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 15.6MB/s]
#
#
# tokenizer.model:   0% 0.00/500k [00:00<?, ?B/s]
#
#
# tokenizer.model: 100% 500k/500k [00:00<00:00, 6.35MB/s]
#
#
#
# model.safetensors:   0% 10.5M/2.20G [00:00<00:42, 51.6MB/s]
#
#
# model.safetensors:   1% 31.5M/2.20G [00:00<00:24, 90.2MB/s]
#
#
# model.safetensors:   2% 41.9M/2.20G [00:00<00:25, 83.2MB/s]
#
#
# model.safetensors:   2% 52.4M/2.20G [00:00<00:32, 66.0MB/s]
#
#
# model.safetensors:   3% 62.9M/2.20G [00:00<00:30, 71.1MB/s]
#
#
# model.safetensors:   3% 73.4M/2.20G [00:01<00:43, 48.6MB/s]
#
#
# model.safetensors:   4% 83.9M/2.20G [00:01<00:56, 37.4MB/s]
#
#
# model.safetensors:   5% 105M/2.20G [00:01<00:43, 48.1MB/s]
#
#
# model.safetensors:   5% 115M/2.20G [00:02<00:45, 46.0MB/s]
#
#
# model.safetensors:   6% 136M/2.20G [00:02<00:42, 48.8MB/s]
#
#
# model.safetensors:   7% 147M/2.20G [00:02<00:42, 48.0MB/s]
#
#
# model.safetensors:   8% 168M/2.20G [00:03<00:36, 55.2MB/s]
#
#
# model.safetensors:   8% 178M/2.20G [00:03<00:38, 53.0MB/s]
#
#
# model.safetensors:   9% 199M/2.20G [00:03<00:34, 57.2MB/s]
#
#
# model.safetensors:  10% 210M/2.20G [00:03<00:40, 49.1MB/s]
#
#
# model.safetensors:  10% 231M/2.20G [00:04<00:37, 52.3MB/s]
#
#
# model.safetensors:  11% 241M/2.20G [00:04<00:35, 54.5MB/s]
#
#
# model.safetensors:  12% 262M/2.20G [00:04<00:34, 56.3MB/s]
#
#
# model.safetensors:  12% 273M/2.20G [00:05<00:45, 42.4MB/s]
#
#
# model.safetensors:  13% 294M/2.20G [00:05<00:46, 41.2MB/s]
#
#
# model.safetensors:  14% 304M/2.20G [00:06<00:54, 34.9MB/s]
#
#
# model.safetensors:  15% 325M/2.20G [00:06<00:52, 35.5MB/s]
#
#
# model.safetensors:  15% 336M/2.20G [00:07<00:53, 34.9MB/s]
#
#
# model.safetensors:  16% 346M/2.20G [00:07<00:51, 35.8MB/s]
#
#
# model.safetensors:  16% 357M/2.20G [00:07<00:50, 36.2MB/s]
#
#
# model.safetensors:  17% 367M/2.20G [00:07<00:42, 43.6MB/s]
#
#
# model.safetensors:  17% 377M/2.20G [00:08<00:41, 43.6MB/s]
#
#
# model.safetensors:  18% 388M/2.20G [00:08<00:41, 43.8MB/s]
#
#
# model.safetensors:  18% 398M/2.20G [00:08<00:47, 37.8MB/s]
#
#
# model.safetensors:  19% 409M/2.20G [00:08<00:42, 42.6MB/s]
#
#
# model.safetensors:  19% 419M/2.20G [00:09<00:45, 38.8MB/s]
#
#
# model.safetensors:  20% 440M/2.20G [00:09<00:40, 44.0MB/s]
#
#
# model.safetensors:  20% 451M/2.20G [00:09<00:40, 43.4MB/s]
#
#
# model.safetensors:  21% 472M/2.20G [00:10<00:40, 43.0MB/s]
#
#
# model.safetensors:  22% 482M/2.20G [00:10<00:42, 40.5MB/s]
#
#
# model.safetensors:  23% 503M/2.20G [00:11<00:37, 45.4MB/s]
#
#
# model.safetensors:  23% 514M/2.20G [00:11<00:40, 41.6MB/s]
#
#
# model.safetensors:  24% 535M/2.20G [00:11<00:41, 39.9MB/s]
#
#
# model.safetensors:  25% 545M/2.20G [00:12<00:40, 41.4MB/s]
#
#
# model.safetensors:  26% 566M/2.20G [00:12<00:40, 40.4MB/s]
#
#
# model.safetensors:  26% 577M/2.20G [00:12<00:41, 39.6MB/s]
#
#
# model.safetensors:  27% 598M/2.20G [00:13<00:32, 49.8MB/s]
#
#
# model.safetensors:  28% 608M/2.20G [00:13<00:36, 44.1MB/s]
#
#
# model.safetensors:  29% 629M/2.20G [00:13<00:33, 47.3MB/s]
#
#
# model.safetensors:  30% 650M/2.20G [00:14<00:30, 51.5MB/s]
#
#
# model.safetensors:  30% 661M/2.20G [00:14<00:32, 48.1MB/s]
#
#
# model.safetensors:  31% 682M/2.20G [00:14<00:30, 49.4MB/s]
#
#
# model.safetensors:  31% 692M/2.20G [00:15<00:31, 47.6MB/s]
#
#
# model.safetensors:  32% 713M/2.20G [00:15<00:28, 51.9MB/s]
#
#
# model.safetensors:  33% 724M/2.20G [00:15<00:29, 49.6MB/s]
#
#
# model.safetensors:  34% 744M/2.20G [00:16<00:24, 60.4MB/s]
#
#
# model.safetensors:  34% 755M/2.20G [00:16<00:28, 50.9MB/s]
#
#
# model.safetensors:  35% 776M/2.20G [00:16<00:25, 55.6MB/s]
#
#
# model.safetensors:  36% 786M/2.20G [00:16<00:26, 52.8MB/s]
#
#
# model.safetensors:  37% 807M/2.20G [00:17<00:24, 56.5MB/s]
#
#
# model.safetensors:  37% 818M/2.20G [00:17<00:28, 48.7MB/s]
#
#
# model.safetensors:  38% 828M/2.20G [00:17<00:27, 50.4MB/s]
#
#
# model.safetensors:  38% 839M/2.20G [00:18<00:28, 48.4MB/s]
#
#
# model.safetensors:  39% 849M/2.20G [00:18<00:27, 49.1MB/s]
#
#
# model.safetensors:  39% 860M/2.20G [00:18<00:24, 55.4MB/s]
#
#
# model.safetensors:  40% 870M/2.20G [00:18<00:27, 47.9MB/s]
#
#
# model.safetensors:  40% 881M/2.20G [00:19<00:35, 37.6MB/s]
#
#
# model.safetensors:  41% 902M/2.20G [00:19<00:33, 38.2MB/s]
#
#
# model.safetensors:  41% 912M/2.20G [00:19<00:31, 40.9MB/s]
#
#
# model.safetensors:  42% 933M/2.20G [00:20<00:28, 44.6MB/s]
#
#
# model.safetensors:  43% 944M/2.20G [00:20<00:27, 45.9MB/s]
#
#
# model.safetensors:  43% 954M/2.20G [00:20<00:29, 42.8MB/s]
#
#
# model.safetensors:  44% 965M/2.20G [00:21<00:31, 39.1MB/s]
#
#
# model.safetensors:  45% 986M/2.20G [00:21<00:26, 46.0MB/s]
#
#
# model.safetensors:  45% 996M/2.20G [00:21<00:29, 41.0MB/s]
#
#
# model.safetensors:  46% 1.02G/2.20G [00:22<00:27, 42.9MB/s]
#
#
# model.safetensors:  47% 1.03G/2.20G [00:22<00:32, 36.1MB/s]
#
#
# model.safetensors:  48% 1.05G/2.20G [00:23<00:28, 39.8MB/s]
#
#
# model.safetensors:  48% 1.06G/2.20G [00:23<00:29, 38.6MB/s]
#
#
# model.safetensors:  49% 1.07G/2.20G [00:23<00:25, 44.7MB/s]
#
#
# model.safetensors:  49% 1.08G/2.20G [00:23<00:29, 38.4MB/s]
#
#
# model.safetensors:  50% 1.09G/2.20G [00:24<00:30, 35.9MB/s]
#
#
# model.safetensors:  51% 1.11G/2.20G [00:24<00:30, 35.6MB/s]
#
#
# model.safetensors:  51% 1.12G/2.20G [00:25<00:31, 34.4MB/s]
#
#
# model.safetensors:  52% 1.14G/2.20G [00:25<00:29, 36.2MB/s]
#
#
# model.safetensors:  52% 1.15G/2.20G [00:26<00:31, 33.7MB/s]
#
#
# model.safetensors:  53% 1.17G/2.20G [00:26<00:26, 38.8MB/s]
#
#
# model.safetensors:  54% 1.18G/2.20G [00:26<00:27, 36.9MB/s]
#
#
# model.safetensors:  55% 1.21G/2.20G [00:27<00:20, 47.7MB/s]
#
#
# model.safetensors:  55% 1.22G/2.20G [00:27<00:24, 40.5MB/s]
#
#
# model.safetensors:  56% 1.24G/2.20G [00:27<00:19, 48.8MB/s]
#
#
# model.safetensors:  57% 1.25G/2.20G [00:27<00:19, 49.4MB/s]
#
#
# model.safetensors:  57% 1.26G/2.20G [00:28<00:18, 51.3MB/s]
#
#
# model.safetensors:  58% 1.27G/2.20G [00:28<00:20, 44.7MB/s]
#
#
# model.safetensors:  59% 1.29G/2.20G [00:28<00:18, 50.0MB/s]
#
#
# model.safetensors:  59% 1.30G/2.20G [00:29<00:21, 42.7MB/s]
#
#
# model.safetensors:  60% 1.32G/2.20G [00:29<00:17, 49.3MB/s]
#
#
# model.safetensors:  61% 1.33G/2.20G [00:29<00:20, 42.8MB/s]
#
#
# model.safetensors:  61% 1.35G/2.20G [00:30<00:18, 45.6MB/s]
#
#
# model.safetensors:  62% 1.36G/2.20G [00:30<00:19, 44.0MB/s]
#
#
# model.safetensors:  63% 1.38G/2.20G [00:30<00:18, 45.3MB/s]
#
#
# model.safetensors:  63% 1.39G/2.20G [00:31<00:16, 48.8MB/s]
#
#
# model.safetensors:  64% 1.42G/2.20G [00:31<00:14, 53.4MB/s]
#
#
# model.safetensors:  65% 1.43G/2.20G [00:31<00:17, 44.7MB/s]
#
#
# model.safetensors:  66% 1.45G/2.20G [00:32<00:21, 35.1MB/s]
#
#
# model.safetensors:  66% 1.46G/2.20G [00:32<00:20, 36.6MB/s]
#
#
# model.safetensors:  67% 1.48G/2.20G [00:33<00:19, 37.2MB/s]
#
#
# model.safetensors:  68% 1.49G/2.20G [00:33<00:19, 37.2MB/s]
#
#
# model.safetensors:  69% 1.51G/2.20G [00:33<00:14, 48.1MB/s]
#
#
# model.safetensors:  69% 1.52G/2.20G [00:34<00:15, 45.0MB/s]
#
#
# model.safetensors:  70% 1.54G/2.20G [00:34<00:13, 47.5MB/s]
#
#
# model.safetensors:  71% 1.56G/2.20G [00:35<00:12, 50.2MB/s]
#
#
# model.safetensors:  71% 1.57G/2.20G [00:35<00:12, 50.2MB/s]
#
#
# model.safetensors:  72% 1.58G/2.20G [00:35<00:11, 53.4MB/s]
#
#
# model.safetensors:  72% 1.59G/2.20G [00:35<00:12, 49.2MB/s]
#
#
# model.safetensors:  73% 1.60G/2.20G [00:35<00:10, 54.8MB/s]
#
#
# model.safetensors:  74% 1.63G/2.20G [00:36<00:11, 48.3MB/s]
#
#
# model.safetensors:  74% 1.64G/2.20G [00:36<00:12, 45.9MB/s]
#
#
# model.safetensors:  75% 1.65G/2.20G [00:36<00:13, 42.0MB/s]
#
#
# model.safetensors:  76% 1.67G/2.20G [00:37<00:11, 45.8MB/s]
#
#
# model.safetensors:  77% 1.69G/2.20G [00:37<00:10, 47.7MB/s]
#
#
# model.safetensors:  77% 1.70G/2.20G [00:37<00:10, 46.9MB/s]
#
#
# model.safetensors:  78% 1.72G/2.20G [00:38<00:09, 51.9MB/s]
#
#
# model.safetensors:  79% 1.73G/2.20G [00:38<00:09, 49.4MB/s]
#
#
# model.safetensors:  80% 1.75G/2.20G [00:38<00:08, 55.5MB/s]
#
#
# model.safetensors:  80% 1.76G/2.20G [00:39<00:09, 47.1MB/s]
#
#
# model.safetensors:  81% 1.78G/2.20G [00:39<00:08, 49.0MB/s]
#
#
# model.safetensors:  81% 1.79G/2.20G [00:39<00:08, 46.7MB/s]
#
#
# model.safetensors:  82% 1.81G/2.20G [00:40<00:06, 55.3MB/s]
#
#
# model.safetensors:  83% 1.82G/2.20G [00:40<00:08, 42.1MB/s]
#
#
# model.safetensors:  84% 1.85G/2.20G [00:41<00:08, 40.7MB/s]
#
#
# model.safetensors:  85% 1.87G/2.20G [00:41<00:06, 49.8MB/s]
#
#
# model.safetensors:  85% 1.88G/2.20G [00:41<00:06, 47.9MB/s]
#
#
# model.safetensors:  86% 1.90G/2.20G [00:41<00:05, 51.6MB/s]
#
#
# model.safetensors:  87% 1.91G/2.20G [00:42<00:07, 41.6MB/s]
#
#
# model.safetensors:  88% 1.93G/2.20G [00:42<00:05, 50.6MB/s]
#
#
# model.safetensors:  88% 1.94G/2.20G [00:43<00:06, 42.5MB/s]
#
#
# model.safetensors:  89% 1.96G/2.20G [00:43<00:04, 50.7MB/s]
#
#
# model.safetensors:  90% 1.97G/2.20G [00:43<00:05, 41.4MB/s]
#
#
# model.safetensors:  91% 1.99G/2.20G [00:43<00:03, 53.3MB/s]
#
#
# model.safetensors:  91% 2.00G/2.20G [00:44<00:04, 46.0MB/s]
#
#
# model.safetensors:  92% 2.02G/2.20G [00:44<00:03, 53.0MB/s]
#
#
# model.safetensors:  92% 2.03G/2.20G [00:44<00:03, 52.7MB/s]
#
#
# model.safetensors:  93% 2.06G/2.20G [00:45<00:02, 52.6MB/s]
#
#
# model.safetensors:  94% 2.07G/2.20G [00:45<00:02, 47.3MB/s]
#
#
# model.safetensors:  95% 2.09G/2.20G [00:45<00:02, 54.3MB/s]
#
#
# model.safetensors:  95% 2.10G/2.20G [00:46<00:02, 42.5MB/s]
#
#
# model.safetensors:  96% 2.12G/2.20G [00:46<00:01, 49.9MB/s]
#
#
# model.safetensors:  97% 2.13G/2.20G [00:46<00:01, 46.5MB/s]
#
#
# model.safetensors:  98% 2.15G/2.20G [00:47<00:01, 46.3MB/s]
#
#
# model.safetensors:  98% 2.16G/2.20G [00:47<00:01, 39.2MB/s]
#
#
# model.safetensors:  99% 2.18G/2.20G [00:48<00:00, 44.7MB/s]
#
#
# model.safetensors: 100% 2.20G/2.20G [00:48<00:00, 45.3MB/s]
#
# Fetching 8 files: 100% 8/8 [00:49<00:00,  6.20s/it]
# Warm up loaders:  20% 1/5 [00:49<03:19, 49.85s/it]
# Fetching 7 files:   0% 0/7 [00:00<?, ?it/s]
#
# special_tokens_map.json: 100% 551/551 [00:00<00:00, 1.86MB/s]
#
#
# generation_config.json: 100% 150/150 [00:00<00:00, 625kB/s]
#
#
# config.json: 100% 687/687 [00:00<00:00, 2.74MB/s]
#
# Fetching 7 files:  14% 1/7 [00:00<00:00,  7.15it/s]
#
# tokenizer_config.json: 100% 1.40k/1.40k [00:00<00:00, 6.49MB/s]
#
#
# trainer_state.json: 100% 3.45k/3.45k [00:00<00:00, 10.4MB/s]
#
#
# tokenizer.model: 100% 500k/500k [00:00<00:00, 5.38MB/s]
#
#
# model.safetensors:   0% 0.00/2.20G [00:00<?, ?B/s]
#
# model.safetensors:   0% 10.5M/2.20G [00:00<00:39, 56.1MB/s]
#
# model.safetensors:   1% 31.5M/2.20G [00:00<00:22, 94.5MB/s]
#
# model.safetensors:   2% 41.9M/2.20G [00:00<00:30, 71.1MB/s]
#
# model.safetensors:   2% 52.4M/2.20G [00:01<00:52, 40.8MB/s]
#
# model.safetensors:   3% 73.4M/2.20G [00:01<00:40, 52.2MB/s]
#
# model.safetensors:   4% 83.9M/2.20G [00:01<00:48, 44.0MB/s]
#
# model.safetensors:   5% 105M/2.20G [00:02<00:51, 40.9MB/s]
#
# model.safetensors:   5% 115M/2.20G [00:02<01:01, 33.6MB/s]
#
# model.safetensors:   6% 136M/2.20G [00:03<00:55, 37.3MB/s]
#
# model.safetensors:   7% 147M/2.20G [00:03<00:53, 38.4MB/s]
#
# model.safetensors:   7% 157M/2.20G [00:04<01:42, 19.9MB/s]
#
# model.safetensors:   8% 168M/2.20G [00:04<01:25, 23.9MB/s]
#
# model.safetensors:   8% 178M/2.20G [00:05<01:08, 29.7MB/s]
#
# model.safetensors:   9% 199M/2.20G [00:05<00:45, 44.2MB/s]
#
# model.safetensors:  10% 220M/2.20G [00:05<00:33, 59.1MB/s]
#
# model.safetensors:  11% 241M/2.20G [00:05<00:30, 63.5MB/s]
#
# model.safetensors:  12% 262M/2.20G [00:06<00:30, 62.7MB/s]
#
# model.safetensors:  12% 273M/2.20G [00:06<00:31, 61.0MB/s]
#
# model.safetensors:  13% 294M/2.20G [00:06<00:33, 57.1MB/s]
#
# model.safetensors:  14% 304M/2.20G [00:06<00:33, 56.6MB/s]
#
# model.safetensors:  15% 325M/2.20G [00:07<00:36, 50.9MB/s]
#
# model.safetensors:  15% 336M/2.20G [00:07<00:32, 56.6MB/s]
#
# model.safetensors:  16% 346M/2.20G [00:07<00:39, 47.1MB/s]
#
# model.safetensors:  16% 357M/2.20G [00:08<00:41, 44.1MB/s]
#
# model.safetensors:  17% 377M/2.20G [00:08<00:37, 49.2MB/s]
#
# model.safetensors:  18% 388M/2.20G [00:08<00:43, 41.8MB/s]
#
# model.safetensors:  18% 398M/2.20G [00:08<00:40, 44.1MB/s]
#
# model.safetensors:  19% 409M/2.20G [00:09<00:36, 49.5MB/s]
#
# model.safetensors:  19% 419M/2.20G [00:09<00:45, 39.1MB/s]
#
# model.safetensors:  20% 440M/2.20G [00:09<00:39, 45.0MB/s]
#
# model.safetensors:  20% 451M/2.20G [00:10<00:42, 40.9MB/s]
#
# model.safetensors:  21% 472M/2.20G [00:10<00:39, 43.2MB/s]
#
# model.safetensors:  22% 482M/2.20G [00:11<00:42, 40.7MB/s]
#
# model.safetensors:  23% 503M/2.20G [00:11<00:36, 46.8MB/s]
#
# model.safetensors:  23% 514M/2.20G [00:11<00:35, 47.1MB/s]
#
# model.safetensors:  24% 524M/2.20G [00:11<00:36, 46.0MB/s]
#
# model.safetensors:  24% 535M/2.20G [00:12<00:35, 46.7MB/s]
#
# model.safetensors:  25% 545M/2.20G [00:12<00:41, 40.2MB/s]
#
# model.safetensors:  26% 566M/2.20G [00:12<00:35, 45.7MB/s]
#
# model.safetensors:  26% 577M/2.20G [00:13<00:39, 40.6MB/s]
#
# model.safetensors:  27% 598M/2.20G [00:13<00:38, 41.6MB/s]
#
# model.safetensors:  28% 608M/2.20G [00:13<00:40, 39.2MB/s]
#
# model.safetensors:  29% 629M/2.20G [00:14<00:34, 45.2MB/s]
#
# model.safetensors:  29% 640M/2.20G [00:14<00:31, 50.0MB/s]
#
# model.safetensors:  30% 650M/2.20G [00:14<00:33, 46.9MB/s]
#
# model.safetensors:  30% 661M/2.20G [00:15<00:38, 39.9MB/s]
#
# model.safetensors:  31% 682M/2.20G [00:15<00:34, 44.0MB/s]
#
# model.safetensors:  31% 692M/2.20G [00:15<00:34, 44.1MB/s]
#
# model.safetensors:  32% 703M/2.20G [00:15<00:34, 43.2MB/s]
#
# model.safetensors:  32% 713M/2.20G [00:16<00:35, 41.7MB/s]
#
# model.safetensors:  33% 724M/2.20G [00:16<00:45, 32.8MB/s]
#
# model.safetensors:  34% 744M/2.20G [00:17<00:41, 35.2MB/s]
#
# model.safetensors:  34% 755M/2.20G [00:17<00:38, 37.3MB/s]
#
# model.safetensors:  35% 776M/2.20G [00:17<00:30, 47.1MB/s]
#
# model.safetensors:  36% 786M/2.20G [00:17<00:29, 47.6MB/s]
#
# model.safetensors:  37% 807M/2.20G [00:18<00:27, 50.4MB/s]
#
# model.safetensors:  37% 818M/2.20G [00:18<00:29, 47.3MB/s]
#
# model.safetensors:  38% 839M/2.20G [00:19<00:28, 47.4MB/s]
#
# model.safetensors:  39% 849M/2.20G [00:19<00:33, 40.2MB/s]
#
# model.safetensors:  39% 860M/2.20G [00:19<00:38, 35.2MB/s]
#
# model.safetensors:  40% 870M/2.20G [00:20<00:38, 34.9MB/s]
#
# model.safetensors:  40% 881M/2.20G [00:20<00:39, 33.6MB/s]
#
# model.safetensors:  41% 891M/2.20G [00:20<00:35, 36.7MB/s]
#
# model.safetensors:  41% 902M/2.20G [00:21<00:36, 35.7MB/s]
#
# model.safetensors:  41% 912M/2.20G [00:21<00:37, 34.0MB/s]
#
# model.safetensors:  42% 933M/2.20G [00:21<00:31, 40.5MB/s]
#
# model.safetensors:  43% 944M/2.20G [00:21<00:27, 46.4MB/s]
#
# model.safetensors:  43% 954M/2.20G [00:22<00:26, 46.2MB/s]
#
# model.safetensors:  44% 965M/2.20G [00:22<00:28, 43.8MB/s]
#
# model.safetensors:  44% 975M/2.20G [00:23<00:39, 30.7MB/s]
#
# model.safetensors:  45% 986M/2.20G [00:23<00:39, 30.7MB/s]
#
# model.safetensors:  45% 996M/2.20G [00:23<00:32, 36.9MB/s]
#
# model.safetensors:  46% 1.01G/2.20G [00:23<00:30, 39.6MB/s]
#
# model.safetensors:  46% 1.02G/2.20G [00:24<00:29, 40.3MB/s]
#
# model.safetensors:  47% 1.03G/2.20G [00:24<00:26, 43.5MB/s]
#
# model.safetensors:  48% 1.05G/2.20G [00:24<00:21, 53.9MB/s]
#
# model.safetensors:  48% 1.06G/2.20G [00:24<00:24, 46.1MB/s]
#
# model.safetensors:  49% 1.08G/2.20G [00:25<00:21, 52.3MB/s]
#
# model.safetensors:  50% 1.09G/2.20G [00:25<00:27, 40.6MB/s]
#
# model.safetensors:  51% 1.11G/2.20G [00:25<00:23, 46.4MB/s]
#
# model.safetensors:  51% 1.12G/2.20G [00:26<00:24, 43.7MB/s]
#
# model.safetensors:  51% 1.13G/2.20G [00:26<00:23, 45.0MB/s]
#
# model.safetensors:  52% 1.14G/2.20G [00:26<00:20, 50.4MB/s]
#
# model.safetensors:  52% 1.15G/2.20G [00:26<00:23, 43.8MB/s]
#
# model.safetensors:  53% 1.17G/2.20G [00:27<00:22, 46.3MB/s]
#
# model.safetensors:  54% 1.18G/2.20G [00:27<00:27, 37.5MB/s]
#
# model.safetensors:  55% 1.21G/2.20G [00:28<00:20, 48.7MB/s]
#
# model.safetensors:  55% 1.22G/2.20G [00:28<00:23, 41.9MB/s]
#
# model.safetensors:  56% 1.24G/2.20G [00:28<00:21, 45.6MB/s]
#
# model.safetensors:  57% 1.25G/2.20G [00:29<00:21, 45.2MB/s]
#
# model.safetensors:  57% 1.26G/2.20G [00:29<00:20, 46.2MB/s]
#
# model.safetensors:  58% 1.27G/2.20G [00:29<00:20, 46.5MB/s]
#
# model.safetensors:  59% 1.29G/2.20G [00:29<00:16, 56.6MB/s]
#
# model.safetensors:  59% 1.30G/2.20G [00:30<00:20, 44.1MB/s]
#
# model.safetensors:  60% 1.32G/2.20G [00:30<00:16, 51.9MB/s]
#
# model.safetensors:  61% 1.33G/2.20G [00:30<00:20, 42.6MB/s]
#
# model.safetensors:  61% 1.34G/2.20G [00:30<00:17, 48.3MB/s]
#
# model.safetensors:  61% 1.35G/2.20G [00:31<00:18, 45.8MB/s]
#
# model.safetensors:  62% 1.36G/2.20G [00:31<00:24, 34.0MB/s]
#
# model.safetensors:  62% 1.37G/2.20G [00:32<00:27, 30.3MB/s]
#
# model.safetensors:  63% 1.38G/2.20G [00:32<00:28, 29.0MB/s]
#
# model.safetensors:  63% 1.39G/2.20G [00:32<00:24, 33.1MB/s]
#
# model.safetensors:  64% 1.42G/2.20G [00:33<00:17, 46.1MB/s]
#
# model.safetensors:  65% 1.43G/2.20G [00:33<00:16, 45.6MB/s]
#
# model.safetensors:  66% 1.45G/2.20G [00:33<00:14, 51.6MB/s]
#
# model.safetensors:  66% 1.46G/2.20G [00:33<00:17, 42.9MB/s]
#
# model.safetensors:  67% 1.48G/2.20G [00:34<00:14, 50.0MB/s]
#
# model.safetensors:  68% 1.49G/2.20G [00:34<00:17, 39.8MB/s]
#
# model.safetensors:  69% 1.51G/2.20G [00:35<00:16, 40.8MB/s]
#
# model.safetensors:  69% 1.52G/2.20G [00:35<00:16, 40.8MB/s]
#
# model.safetensors:  70% 1.53G/2.20G [00:35<00:14, 47.3MB/s]
#
# model.safetensors:  70% 1.54G/2.20G [00:35<00:14, 44.6MB/s]
#
# model.safetensors:  71% 1.56G/2.20G [00:36<00:11, 54.0MB/s]
#
# model.safetensors:  71% 1.57G/2.20G [00:36<00:11, 55.5MB/s]
#
# model.safetensors:  72% 1.59G/2.20G [00:36<00:09, 61.3MB/s]
#
# model.safetensors:  73% 1.60G/2.20G [00:36<00:10, 56.3MB/s]
#
# model.safetensors:  74% 1.63G/2.20G [00:37<00:10, 54.6MB/s]
#
# model.safetensors:  74% 1.64G/2.20G [00:37<00:15, 36.3MB/s]
#
# model.safetensors:  75% 1.66G/2.20G [00:38<00:12, 44.7MB/s]
#
# model.safetensors:  76% 1.67G/2.20G [00:38<00:12, 42.5MB/s]
#
# model.safetensors:  77% 1.69G/2.20G [00:38<00:11, 43.0MB/s]
#
# model.safetensors:  77% 1.70G/2.20G [00:39<00:11, 42.4MB/s]
#
# model.safetensors:  78% 1.71G/2.20G [00:39<00:10, 47.3MB/s]
#
# model.safetensors:  78% 1.72G/2.20G [00:39<00:10, 47.0MB/s]
#
# model.safetensors:  79% 1.73G/2.20G [00:39<00:10, 45.8MB/s]
#
# model.safetensors:  80% 1.75G/2.20G [00:40<00:09, 45.6MB/s]
#
# model.safetensors:  80% 1.76G/2.20G [00:40<00:11, 38.2MB/s]
#
# model.safetensors:  81% 1.78G/2.20G [00:40<00:08, 48.3MB/s]
#
# model.safetensors:  81% 1.79G/2.20G [00:41<00:08, 47.1MB/s]
#
# model.safetensors:  82% 1.81G/2.20G [00:41<00:07, 51.8MB/s]
#
# model.safetensors:  83% 1.82G/2.20G [00:42<00:09, 38.4MB/s]
#
# model.safetensors:  83% 1.84G/2.20G [00:42<00:08, 41.8MB/s]
#
# model.safetensors:  84% 1.85G/2.20G [00:42<00:09, 38.4MB/s]
#
# model.safetensors:  84% 1.86G/2.20G [00:42<00:07, 45.5MB/s]
#
# model.safetensors:  85% 1.87G/2.20G [00:42<00:07, 45.8MB/s]
#
# model.safetensors:  85% 1.88G/2.20G [00:43<00:07, 46.0MB/s]
#
# model.safetensors:  86% 1.89G/2.20G [00:43<00:05, 54.8MB/s]
#
# model.safetensors:  86% 1.90G/2.20G [00:43<00:05, 53.8MB/s]
#
# model.safetensors:  87% 1.91G/2.20G [00:43<00:06, 47.3MB/s]
#
# model.safetensors:  88% 1.93G/2.20G [00:44<00:05, 53.3MB/s]
#
# model.safetensors:  88% 1.94G/2.20G [00:44<00:04, 52.2MB/s]
#
# model.safetensors:  89% 1.96G/2.20G [00:44<00:04, 56.9MB/s]
#
# model.safetensors:  90% 1.97G/2.20G [00:44<00:04, 47.0MB/s]
#
# model.safetensors:  91% 1.99G/2.20G [00:45<00:03, 52.4MB/s]
#
# model.safetensors:  91% 2.00G/2.20G [00:45<00:03, 50.6MB/s]
#
# model.safetensors:  92% 2.02G/2.20G [00:45<00:03, 52.0MB/s]
#
# model.safetensors:  92% 2.03G/2.20G [00:46<00:03, 45.6MB/s]
#
# model.safetensors:  93% 2.06G/2.20G [00:46<00:03, 43.5MB/s]
#
# model.safetensors:  94% 2.07G/2.20G [00:47<00:03, 43.1MB/s]
#
# model.safetensors:  95% 2.09G/2.20G [00:47<00:02, 51.6MB/s]
#
# model.safetensors:  95% 2.10G/2.20G [00:47<00:02, 44.8MB/s]
#
# model.safetensors:  96% 2.12G/2.20G [00:48<00:01, 41.5MB/s]
#
# model.safetensors:  97% 2.13G/2.20G [00:48<00:01, 44.4MB/s]
#
# model.safetensors:  98% 2.15G/2.20G [00:48<00:01, 43.4MB/s]
#
# model.safetensors:  98% 2.16G/2.20G [00:49<00:00, 44.1MB/s]
#
# model.safetensors:  99% 2.18G/2.20G [00:49<00:00, 45.4MB/s]
#
# model.safetensors: 100% 2.20G/2.20G [00:49<00:00, 44.1MB/s]
#
# Fetching 7 files: 100% 7/7 [00:50<00:00,  7.21s/it]
# Warm up loaders:  40% 2/5 [01:40<02:31, 50.34s/it]
# Fetching 10 files:   0% 0/10 [00:00<?, ?it/s]
#
# generation_config.json: 100% 145/145 [00:00<00:00, 678kB/s]
#
#
# special_tokens_map.json: 100% 549/549 [00:00<00:00, 2.99MB/s]
#
#
# eval_results.json: 100% 188/188 [00:00<00:00, 498kB/s]
#
#
# config.json: 100% 682/682 [00:00<00:00, 3.33MB/s]
#
#
# all_results.json: 100% 363/363 [00:00<00:00, 2.43MB/s]
#
# Fetching 10 files:  10% 1/10 [00:00<00:01,  6.78it/s]
#
# tokenizer.model: 100% 500k/500k [00:00<00:00, 34.7MB/s]
#
#
# train_results.json: 100% 195/195 [00:00<00:00, 819kB/s]
#
#
# tokenizer_config.json: 100% 1.60k/1.60k [00:00<00:00, 7.37MB/s]
#
#
# trainer_state.json: 100% 56.1k/56.1k [00:00<00:00, 2.34MB/s]
#
#
# model.safetensors:   0% 0.00/2.20G [00:00<?, ?B/s]
#
# model.safetensors:   0% 10.5M/2.20G [00:00<01:02, 34.8MB/s]
#
# model.safetensors:   1% 31.5M/2.20G [00:00<00:30, 72.3MB/s]
#
# model.safetensors:   2% 41.9M/2.20G [00:00<00:34, 61.9MB/s]
#
# model.safetensors:   2% 52.4M/2.20G [00:00<00:42, 50.5MB/s]
#
# model.safetensors:   3% 73.4M/2.20G [00:01<00:34, 62.1MB/s]
#
# model.safetensors:   4% 83.9M/2.20G [00:01<00:36, 57.3MB/s]
#
# model.safetensors:   5% 105M/2.20G [00:01<00:33, 63.0MB/s]
#
# model.safetensors:   5% 115M/2.20G [00:02<00:37, 55.0MB/s]
#
# model.safetensors:   6% 136M/2.20G [00:02<00:36, 57.2MB/s]
#
# model.safetensors:   7% 147M/2.20G [00:02<00:37, 55.0MB/s]
#
# model.safetensors:   8% 168M/2.20G [00:03<00:48, 41.7MB/s]
#
# model.safetensors:   8% 178M/2.20G [00:03<00:42, 47.4MB/s]
#
# model.safetensors:   9% 199M/2.20G [00:03<00:35, 56.0MB/s]
#
# model.safetensors:  10% 210M/2.20G [00:03<00:35, 56.3MB/s]
#
# model.safetensors:  10% 220M/2.20G [00:03<00:31, 62.5MB/s]
#
# model.safetensors:  10% 231M/2.20G [00:04<00:40, 48.9MB/s]
#
# model.safetensors:  11% 241M/2.20G [00:04<00:42, 45.9MB/s]
#
# model.safetensors:  11% 252M/2.20G [00:04<00:36, 54.0MB/s]
#
# model.safetensors:  12% 262M/2.20G [00:04<00:38, 49.9MB/s]
#
# model.safetensors:  12% 273M/2.20G [00:05<00:44, 43.2MB/s]
#
# model.safetensors:  13% 294M/2.20G [00:05<00:37, 51.3MB/s]
#
# model.safetensors:  14% 304M/2.20G [00:05<00:40, 46.6MB/s]
#
# model.safetensors:  15% 325M/2.20G [00:06<00:31, 59.5MB/s]
#
# model.safetensors:  16% 346M/2.20G [00:06<00:26, 71.0MB/s]
#
# model.safetensors:  16% 357M/2.20G [00:06<00:35, 51.8MB/s]
#
# model.safetensors:  17% 367M/2.20G [00:06<00:33, 54.4MB/s]
#
# model.safetensors:  17% 377M/2.20G [00:07<00:34, 53.1MB/s]
#
# model.safetensors:  18% 388M/2.20G [00:07<00:34, 52.3MB/s]
#
# model.safetensors:  18% 398M/2.20G [00:07<00:32, 55.9MB/s]
#
# model.safetensors:  19% 409M/2.20G [00:07<00:32, 54.8MB/s]
#
# model.safetensors:  19% 419M/2.20G [00:08<00:46, 38.2MB/s]
#
# model.safetensors:  20% 440M/2.20G [00:08<00:37, 46.9MB/s]
#
# model.safetensors:  20% 451M/2.20G [00:08<00:45, 38.8MB/s]
#
# model.safetensors:  21% 472M/2.20G [00:09<00:36, 47.9MB/s]
#
# model.safetensors:  22% 482M/2.20G [00:09<00:37, 45.3MB/s]
#
# model.safetensors:  22% 493M/2.20G [00:09<00:33, 51.1MB/s]
#
# model.safetensors:  23% 503M/2.20G [00:09<00:33, 51.0MB/s]
#
# model.safetensors:  23% 514M/2.20G [00:10<00:38, 43.9MB/s]
#
# model.safetensors:  24% 535M/2.20G [00:10<00:41, 40.5MB/s]
#
# model.safetensors:  25% 545M/2.20G [00:10<00:39, 41.5MB/s]
#
# model.safetensors:  26% 566M/2.20G [00:11<00:35, 46.4MB/s]
#
# model.safetensors:  26% 577M/2.20G [00:11<00:41, 39.4MB/s]
#
# model.safetensors:  27% 598M/2.20G [00:12<00:39, 40.4MB/s]
#
# model.safetensors:  28% 608M/2.20G [00:12<00:41, 38.6MB/s]
#
# model.safetensors:  29% 629M/2.20G [00:12<00:35, 44.3MB/s]
#
# model.safetensors:  29% 640M/2.20G [00:12<00:31, 49.9MB/s]
#
# model.safetensors:  30% 650M/2.20G [00:13<00:36, 42.0MB/s]
#
# model.safetensors:  30% 661M/2.20G [00:13<00:36, 41.6MB/s]
#
# model.safetensors:  31% 682M/2.20G [00:13<00:29, 51.9MB/s]
#
# model.safetensors:  31% 692M/2.20G [00:14<00:30, 49.3MB/s]
#
# model.safetensors:  32% 713M/2.20G [00:14<00:28, 52.1MB/s]
#
# model.safetensors:  33% 724M/2.20G [00:14<00:32, 45.2MB/s]
#
# model.safetensors:  34% 744M/2.20G [00:15<00:27, 52.2MB/s]
#
# model.safetensors:  34% 755M/2.20G [00:15<00:31, 45.7MB/s]
#
# model.safetensors:  35% 776M/2.20G [00:16<00:37, 38.1MB/s]
#
# model.safetensors:  36% 786M/2.20G [00:16<00:36, 39.1MB/s]
#
# model.safetensors:  36% 797M/2.20G [00:16<00:33, 42.4MB/s]
#
# model.safetensors:  37% 807M/2.20G [00:16<00:35, 39.6MB/s]
#
# model.safetensors:  37% 818M/2.20G [00:17<00:32, 42.5MB/s]
#
# model.safetensors:  38% 839M/2.20G [00:17<00:24, 56.2MB/s]
#
# model.safetensors:  39% 849M/2.20G [00:17<00:28, 48.1MB/s]
#
# model.safetensors:  40% 870M/2.20G [00:18<00:32, 40.9MB/s]
#
# model.safetensors:  40% 881M/2.20G [00:18<00:30, 43.6MB/s]
#
# model.safetensors:  41% 902M/2.20G [00:18<00:24, 52.7MB/s]
#
# model.safetensors:  41% 912M/2.20G [00:18<00:24, 52.6MB/s]
#
# model.safetensors:  42% 933M/2.20G [00:19<00:21, 58.8MB/s]
#
# model.safetensors:  43% 944M/2.20G [00:19<00:19, 64.7MB/s]
#
# model.safetensors:  43% 954M/2.20G [00:19<00:21, 59.0MB/s]
#
# model.safetensors:  44% 965M/2.20G [00:19<00:27, 45.3MB/s]
#
# model.safetensors:  44% 975M/2.20G [00:19<00:23, 53.0MB/s]
#
# model.safetensors:  45% 986M/2.20G [00:20<00:29, 40.8MB/s]
#
# model.safetensors:  45% 996M/2.20G [00:20<00:29, 40.9MB/s]
#
# model.safetensors:  46% 1.02G/2.20G [00:21<00:26, 44.4MB/s]
#
# model.safetensors:  47% 1.03G/2.20G [00:21<00:31, 37.6MB/s]
#
# model.safetensors:  47% 1.04G/2.20G [00:22<00:40, 28.6MB/s]
#
# model.safetensors:  48% 1.05G/2.20G [00:22<00:35, 32.9MB/s]
#
# model.safetensors:  48% 1.06G/2.20G [00:22<00:29, 39.2MB/s]
#
# model.safetensors:  49% 1.08G/2.20G [00:22<00:20, 55.4MB/s]
#
# model.safetensors:  50% 1.10G/2.20G [00:22<00:15, 70.9MB/s]
#
# model.safetensors:  51% 1.11G/2.20G [00:22<00:16, 67.6MB/s]
#
# model.safetensors:  51% 1.12G/2.20G [00:23<00:17, 61.6MB/s]
#
# model.safetensors:  51% 1.13G/2.20G [00:23<00:16, 62.9MB/s]
#
# model.safetensors:  52% 1.14G/2.20G [00:23<00:20, 52.6MB/s]
#
# model.safetensors:  52% 1.15G/2.20G [00:23<00:22, 46.1MB/s]
#
# model.safetensors:  53% 1.17G/2.20G [00:24<00:16, 63.8MB/s]
#
# model.safetensors:  54% 1.18G/2.20G [00:24<00:17, 57.5MB/s]
#
# model.safetensors:  55% 1.21G/2.20G [00:24<00:16, 59.9MB/s]
#
# model.safetensors:  55% 1.22G/2.20G [00:24<00:18, 51.9MB/s]
#
# model.safetensors:  56% 1.24G/2.20G [00:25<00:16, 57.7MB/s]
#
# model.safetensors:  57% 1.25G/2.20G [00:25<00:15, 59.9MB/s]
#
# model.safetensors:  57% 1.26G/2.20G [00:25<00:17, 53.0MB/s]
#
# model.safetensors:  58% 1.27G/2.20G [00:25<00:16, 55.7MB/s]
#
# model.safetensors:  59% 1.29G/2.20G [00:26<00:15, 60.1MB/s]
#
# model.safetensors:  59% 1.30G/2.20G [00:26<00:15, 58.9MB/s]
#
# model.safetensors:  60% 1.32G/2.20G [00:26<00:15, 57.3MB/s]
#
# model.safetensors:  61% 1.33G/2.20G [00:27<00:17, 49.6MB/s]
#
# model.safetensors:  61% 1.35G/2.20G [00:27<00:14, 57.4MB/s]
#
# model.safetensors:  62% 1.36G/2.20G [00:27<00:14, 57.6MB/s]
#
# model.safetensors:  63% 1.38G/2.20G [00:27<00:12, 67.4MB/s]
#
# model.safetensors:  63% 1.39G/2.20G [00:28<00:17, 46.9MB/s]
#
# model.safetensors:  64% 1.41G/2.20G [00:28<00:14, 53.5MB/s]
#
# model.safetensors:  64% 1.42G/2.20G [00:28<00:15, 52.1MB/s]
#
# model.safetensors:  65% 1.43G/2.20G [00:28<00:15, 51.2MB/s]
#
# model.safetensors:  66% 1.45G/2.20G [00:28<00:12, 61.3MB/s]
#
# model.safetensors:  66% 1.46G/2.20G [00:29<00:14, 51.4MB/s]
#
# model.safetensors:  67% 1.48G/2.20G [00:29<00:13, 53.4MB/s]
#
# model.safetensors:  68% 1.49G/2.20G [00:29<00:14, 50.2MB/s]
#
# model.safetensors:  69% 1.51G/2.20G [00:30<00:13, 53.0MB/s]
#
# model.safetensors:  69% 1.52G/2.20G [00:30<00:13, 50.7MB/s]
#
# model.safetensors:  70% 1.54G/2.20G [00:30<00:12, 51.9MB/s]
#
# model.safetensors:  71% 1.55G/2.20G [00:31<00:11, 56.1MB/s]
#
# model.safetensors:  71% 1.56G/2.20G [00:31<00:11, 54.2MB/s]
#
# model.safetensors:  71% 1.57G/2.20G [00:31<00:13, 46.4MB/s]
#
# model.safetensors:  72% 1.58G/2.20G [00:31<00:13, 44.2MB/s]
#
# model.safetensors:  72% 1.59G/2.20G [00:32<00:15, 38.7MB/s]
#
# model.safetensors:  73% 1.60G/2.20G [00:32<00:16, 36.8MB/s]
#
# model.safetensors:  73% 1.61G/2.20G [00:32<00:13, 43.0MB/s]
#
# model.safetensors:  74% 1.63G/2.20G [00:32<00:12, 46.1MB/s]
#
# model.safetensors:  74% 1.64G/2.20G [00:32<00:10, 51.7MB/s]
#
# model.safetensors:  75% 1.66G/2.20G [00:33<00:10, 50.1MB/s]
#
# model.safetensors:  76% 1.67G/2.20G [00:33<00:14, 37.0MB/s]
#
# model.safetensors:  77% 1.69G/2.20G [00:34<00:11, 44.3MB/s]
#
# model.safetensors:  77% 1.70G/2.20G [00:34<00:10, 46.2MB/s]
#
# model.safetensors:  78% 1.72G/2.20G [00:34<00:09, 50.3MB/s]
#
# model.safetensors:  79% 1.73G/2.20G [00:35<00:09, 51.2MB/s]
#
# model.safetensors:  80% 1.75G/2.20G [00:35<00:07, 59.2MB/s]
#
# model.safetensors:  80% 1.76G/2.20G [00:35<00:07, 55.2MB/s]
#
# model.safetensors:  81% 1.78G/2.20G [00:35<00:07, 54.6MB/s]
#
# model.safetensors:  81% 1.79G/2.20G [00:36<00:09, 44.4MB/s]
#
# model.safetensors:  82% 1.81G/2.20G [00:36<00:07, 50.5MB/s]
#
# model.safetensors:  83% 1.82G/2.20G [00:36<00:07, 50.7MB/s]
#
# model.safetensors:  84% 1.85G/2.20G [00:37<00:06, 51.3MB/s]
#
# model.safetensors:  85% 1.87G/2.20G [00:37<00:05, 61.6MB/s]
#
# model.safetensors:  85% 1.88G/2.20G [00:37<00:05, 57.7MB/s]
#
# model.safetensors:  86% 1.90G/2.20G [00:38<00:05, 53.6MB/s]
#
# model.safetensors:  87% 1.91G/2.20G [00:38<00:05, 54.3MB/s]
#
# model.safetensors:  88% 1.93G/2.20G [00:38<00:05, 51.4MB/s]
#
# model.safetensors:  88% 1.94G/2.20G [00:38<00:04, 54.1MB/s]
#
# model.safetensors:  89% 1.96G/2.20G [00:39<00:04, 56.9MB/s]
#
# model.safetensors:  90% 1.97G/2.20G [00:39<00:04, 52.6MB/s]
#
# model.safetensors:  91% 1.99G/2.20G [00:40<00:04, 46.2MB/s]
#
# model.safetensors:  91% 2.00G/2.20G [00:40<00:04, 49.2MB/s]
#
# model.safetensors:  92% 2.02G/2.20G [00:40<00:03, 50.6MB/s]
#
# model.safetensors:  92% 2.03G/2.20G [00:40<00:03, 42.4MB/s]
#
# model.safetensors:  93% 2.06G/2.20G [00:41<00:03, 43.3MB/s]
#
# model.safetensors:  94% 2.07G/2.20G [00:41<00:03, 41.3MB/s]
#
# model.safetensors:  95% 2.09G/2.20G [00:42<00:02, 50.9MB/s]
#
# model.safetensors:  95% 2.10G/2.20G [00:42<00:01, 56.2MB/s]
#
# model.safetensors:  96% 2.11G/2.20G [00:42<00:02, 41.7MB/s]
#
# model.safetensors:  96% 2.12G/2.20G [00:43<00:02, 34.1MB/s]
#
# model.safetensors:  97% 2.13G/2.20G [00:43<00:02, 31.5MB/s]
#
# model.safetensors:  97% 2.14G/2.20G [00:43<00:01, 35.2MB/s]
#
# model.safetensors:  98% 2.15G/2.20G [00:44<00:01, 34.1MB/s]
#
# model.safetensors:  98% 2.16G/2.20G [00:44<00:01, 39.8MB/s]
#
# model.safetensors:  99% 2.18G/2.20G [00:44<00:00, 47.8MB/s]
#
# model.safetensors: 100% 2.19G/2.20G [00:44<00:00, 52.3MB/s]
#
# model.safetensors: 100% 2.20G/2.20G [00:44<00:00, 49.0MB/s]
#
# Fetching 10 files: 100% 10/10 [00:45<00:00,  4.52s/it]
# Warm up loaders:  60% 3/5 [02:26<01:36, 48.12s/it]
# Fetching 8 files: 100% 8/8 [00:00<00:00, 98689.51it/s]
# Warm up loaders:  80% 4/5 [02:26<00:29, 29.20s/it]
# Fetching 7 files:   0% 0/7 [00:00<?, ?it/s]
#
# config.json: 100% 560/560 [00:00<00:00, 3.09MB/s]
#
# Fetching 7 files:  14% 1/7 [00:00<00:00,  8.99it/s]
#
# tokenizer.json:   0% 0.00/1.84M [00:00<?, ?B/s]
#
#
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 1.42MB/s]
#
#
#
# tokenizer_config.json: 100% 776/776 [00:00<00:00, 3.48MB/s]
#
#
#
# generation_config.json: 100% 129/129 [00:00<00:00, 390kB/s]
#
#
#
# tokenizer.model: 100% 500k/500k [00:00<00:00, 188MB/s]
#
#
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 15.8MB/s]
#
#
# model.safetensors:   0% 0.00/2.20G [00:00<?, ?B/s]
#
# model.safetensors:   0% 10.5M/2.20G [00:00<00:43, 50.9MB/s]
#
# model.safetensors:   1% 21.0M/2.20G [00:00<00:34, 63.5MB/s]
#
# model.safetensors:   1% 31.5M/2.20G [00:00<00:55, 39.1MB/s]
#
# model.safetensors:   2% 41.9M/2.20G [00:01<00:58, 36.9MB/s]
#
# model.safetensors:   2% 52.4M/2.20G [00:01<01:03, 34.1MB/s]
#
# model.safetensors:   3% 73.4M/2.20G [00:01<00:50, 42.2MB/s]
#
# model.safetensors:   4% 83.9M/2.20G [00:02<00:54, 38.8MB/s]
#
# model.safetensors:   5% 105M/2.20G [00:02<00:49, 42.3MB/s]
#
# model.safetensors:   5% 115M/2.20G [00:02<00:50, 41.0MB/s]
#
# model.safetensors:   6% 136M/2.20G [00:03<00:44, 46.8MB/s]
#
# model.safetensors:   7% 147M/2.20G [00:03<00:48, 42.4MB/s]
#
# model.safetensors:   7% 157M/2.20G [00:03<00:42, 47.9MB/s]
#
# model.safetensors:   8% 168M/2.20G [00:03<00:49, 41.3MB/s]
#
# model.safetensors:   8% 178M/2.20G [00:04<01:04, 31.6MB/s]
#
# model.safetensors:   9% 199M/2.20G [00:04<00:50, 39.6MB/s]
#
# model.safetensors:  10% 210M/2.20G [00:05<00:44, 44.4MB/s]
#
# model.safetensors:  10% 231M/2.20G [00:05<00:42, 46.5MB/s]
#
# model.safetensors:  11% 241M/2.20G [00:05<00:44, 44.0MB/s]
#
# model.safetensors:  12% 262M/2.20G [00:05<00:33, 57.3MB/s]
#
# model.safetensors:  12% 273M/2.20G [00:06<00:38, 50.2MB/s]
#
# model.safetensors:  13% 294M/2.20G [00:06<00:36, 52.4MB/s]
#
# model.safetensors:  14% 304M/2.20G [00:07<00:45, 41.4MB/s]
#
# model.safetensors:  15% 325M/2.20G [00:07<00:45, 41.7MB/s]
#
# model.safetensors:  15% 336M/2.20G [00:07<00:44, 41.6MB/s]
#
# model.safetensors:  16% 346M/2.20G [00:08<00:48, 37.9MB/s]
#
# model.safetensors:  16% 357M/2.20G [00:08<00:49, 37.4MB/s]
#
# model.safetensors:  17% 377M/2.20G [00:08<00:45, 40.1MB/s]
#
# model.safetensors:  18% 388M/2.20G [00:09<00:45, 39.4MB/s]
#
# model.safetensors:  19% 409M/2.20G [00:09<00:44, 40.4MB/s]
#
# model.safetensors:  19% 419M/2.20G [00:10<00:47, 37.9MB/s]
#
# model.safetensors:  20% 440M/2.20G [00:10<00:41, 42.9MB/s]
#
# model.safetensors:  20% 451M/2.20G [00:10<00:46, 37.7MB/s]
#
# model.safetensors:  21% 472M/2.20G [00:11<00:46, 37.5MB/s]
#
# model.safetensors:  22% 482M/2.20G [00:11<00:46, 36.8MB/s]
#
# model.safetensors:  23% 503M/2.20G [00:12<00:47, 35.7MB/s]
#
# model.safetensors:  23% 514M/2.20G [00:12<00:45, 37.1MB/s]
#
# model.safetensors:  24% 535M/2.20G [00:13<00:42, 39.3MB/s]
#
# model.safetensors:  25% 545M/2.20G [00:13<00:49, 33.3MB/s]
#
# model.safetensors:  26% 566M/2.20G [00:13<00:41, 39.4MB/s]
#
# model.safetensors:  26% 577M/2.20G [00:14<00:42, 37.8MB/s]
#
# model.safetensors:  27% 598M/2.20G [00:14<00:35, 45.2MB/s]
#
# model.safetensors:  28% 608M/2.20G [00:14<00:40, 39.2MB/s]
#
# model.safetensors:  29% 629M/2.20G [00:15<00:53, 29.1MB/s]
#
# model.safetensors:  29% 640M/2.20G [00:16<00:46, 33.3MB/s]
#
# model.safetensors:  30% 650M/2.20G [00:16<00:41, 37.1MB/s]
#
# model.safetensors:  30% 661M/2.20G [00:16<00:38, 39.8MB/s]
#
# model.safetensors:  31% 682M/2.20G [00:17<00:38, 39.2MB/s]
#
# model.safetensors:  31% 692M/2.20G [00:17<00:35, 42.3MB/s]
#
# model.safetensors:  32% 713M/2.20G [00:17<00:29, 49.7MB/s]
#
# model.safetensors:  33% 724M/2.20G [00:17<00:32, 45.6MB/s]
#
# model.safetensors:  34% 744M/2.20G [00:18<00:33, 44.0MB/s]
#
# model.safetensors:  34% 755M/2.20G [00:18<00:32, 44.6MB/s]
#
# model.safetensors:  35% 776M/2.20G [00:18<00:26, 53.4MB/s]
#
# model.safetensors:  36% 786M/2.20G [00:19<00:30, 46.3MB/s]
#
# model.safetensors:  37% 807M/2.20G [00:19<00:29, 46.7MB/s]
#
# model.safetensors:  37% 818M/2.20G [00:20<00:35, 38.5MB/s]
#
# model.safetensors:  38% 839M/2.20G [00:20<00:31, 43.5MB/s]
#
# model.safetensors:  39% 849M/2.20G [00:20<00:33, 40.2MB/s]
#
# model.safetensors:  40% 870M/2.20G [00:21<00:29, 45.2MB/s]
#
# model.safetensors:  40% 881M/2.20G [00:21<00:30, 43.5MB/s]
#
# model.safetensors:  41% 891M/2.20G [00:21<00:32, 40.4MB/s]
#
# model.safetensors:  41% 912M/2.20G [00:21<00:23, 54.8MB/s]
#
# model.safetensors:  42% 933M/2.20G [00:22<00:21, 59.4MB/s]
#
# model.safetensors:  43% 954M/2.20G [00:22<00:19, 65.2MB/s]
#
# model.safetensors:  44% 965M/2.20G [00:22<00:23, 53.4MB/s]
#
# model.safetensors:  45% 986M/2.20G [00:23<00:23, 52.8MB/s]
#
# model.safetensors:  45% 996M/2.20G [00:23<00:22, 53.7MB/s]
#
# model.safetensors:  46% 1.01G/2.20G [00:23<00:20, 58.5MB/s]
#
# model.safetensors:  46% 1.02G/2.20G [00:23<00:23, 51.0MB/s]
#
# model.safetensors:  47% 1.03G/2.20G [00:24<00:28, 41.5MB/s]
#
# model.safetensors:  48% 1.05G/2.20G [00:24<00:26, 44.0MB/s]
#
# model.safetensors:  48% 1.06G/2.20G [00:24<00:27, 41.4MB/s]
#
# model.safetensors:  49% 1.08G/2.20G [00:25<00:24, 46.5MB/s]
#
# model.safetensors:  50% 1.09G/2.20G [00:25<00:27, 40.1MB/s]
#
# model.safetensors:  50% 1.10G/2.20G [00:25<00:24, 44.6MB/s]
#
# model.safetensors:  51% 1.11G/2.20G [00:25<00:22, 48.4MB/s]
#
# model.safetensors:  51% 1.12G/2.20G [00:26<00:22, 48.6MB/s]
#
# model.safetensors:  52% 1.14G/2.20G [00:26<00:19, 54.6MB/s]
#
# model.safetensors:  52% 1.15G/2.20G [00:26<00:23, 45.1MB/s]
#
# model.safetensors:  53% 1.17G/2.20G [00:27<00:20, 48.9MB/s]
#
# model.safetensors:  54% 1.18G/2.20G [00:27<00:20, 50.7MB/s]
#
# model.safetensors:  55% 1.21G/2.20G [00:28<00:22, 44.8MB/s]
#
# model.safetensors:  55% 1.22G/2.20G [00:28<00:25, 39.3MB/s]
#
# model.safetensors:  56% 1.24G/2.20G [00:28<00:23, 41.5MB/s]
#
# model.safetensors:  57% 1.25G/2.20G [00:29<00:21, 44.6MB/s]
#
# model.safetensors:  57% 1.26G/2.20G [00:29<00:19, 47.5MB/s]
#
# model.safetensors:  58% 1.27G/2.20G [00:29<00:22, 41.6MB/s]
#
# model.safetensors:  59% 1.29G/2.20G [00:29<00:18, 48.5MB/s]
#
# model.safetensors:  59% 1.30G/2.20G [00:30<00:18, 48.0MB/s]
#
# model.safetensors:  60% 1.31G/2.20G [00:30<00:16, 54.3MB/s]
#
# model.safetensors:  60% 1.32G/2.20G [00:30<00:16, 54.1MB/s]
#
# model.safetensors:  61% 1.33G/2.20G [00:30<00:18, 45.7MB/s]
#
# model.safetensors:  61% 1.35G/2.20G [00:31<00:17, 48.6MB/s]
#
# model.safetensors:  62% 1.36G/2.20G [00:31<00:19, 43.0MB/s]
#
# model.safetensors:  63% 1.38G/2.20G [00:31<00:18, 44.7MB/s]
#
# model.safetensors:  63% 1.39G/2.20G [00:32<00:19, 40.5MB/s]
#
# model.safetensors:  64% 1.42G/2.20G [00:32<00:17, 43.7MB/s]
#
# model.safetensors:  65% 1.43G/2.20G [00:32<00:17, 45.4MB/s]
#
# model.safetensors:  66% 1.45G/2.20G [00:33<00:13, 56.1MB/s]
#
# model.safetensors:  66% 1.46G/2.20G [00:33<00:16, 44.4MB/s]
#
# model.safetensors:  67% 1.48G/2.20G [00:33<00:15, 47.7MB/s]
#
# model.safetensors:  68% 1.49G/2.20G [00:34<00:16, 43.4MB/s]
#
# model.safetensors:  69% 1.51G/2.20G [00:34<00:15, 44.9MB/s]
#
# model.safetensors:  69% 1.52G/2.20G [00:34<00:14, 46.8MB/s]
#
# model.safetensors:  70% 1.54G/2.20G [00:35<00:13, 49.3MB/s]
#
# model.safetensors:  71% 1.55G/2.20G [00:35<00:12, 52.6MB/s]
#
# model.safetensors:  71% 1.56G/2.20G [00:35<00:11, 54.7MB/s]
#
# model.safetensors:  71% 1.57G/2.20G [00:35<00:13, 47.0MB/s]
#
# model.safetensors:  72% 1.58G/2.20G [00:36<00:13, 47.3MB/s]
#
# model.safetensors:  72% 1.59G/2.20G [00:36<00:12, 49.4MB/s]
#
# model.safetensors:  73% 1.60G/2.20G [00:36<00:13, 44.0MB/s]
#
# model.safetensors:  74% 1.63G/2.20G [00:36<00:11, 48.9MB/s]
#
# model.safetensors:  74% 1.64G/2.20G [00:37<00:12, 43.5MB/s]
#
# model.safetensors:  75% 1.66G/2.20G [00:37<00:09, 56.1MB/s]
#
# model.safetensors:  76% 1.67G/2.20G [00:37<00:10, 51.0MB/s]
#
# model.safetensors:  77% 1.69G/2.20G [00:38<00:10, 48.1MB/s]
#
# model.safetensors:  77% 1.70G/2.20G [00:38<00:11, 44.3MB/s]
#
# model.safetensors:  78% 1.72G/2.20G [00:38<00:10, 46.6MB/s]
#
# model.safetensors:  79% 1.73G/2.20G [00:39<00:09, 51.4MB/s]
#
# model.safetensors:  80% 1.75G/2.20G [00:39<00:08, 53.7MB/s]
#
# model.safetensors:  80% 1.76G/2.20G [00:39<00:07, 54.9MB/s]
#
# model.safetensors:  81% 1.78G/2.20G [00:40<00:07, 54.3MB/s]
#
# model.safetensors:  81% 1.79G/2.20G [00:40<00:08, 46.9MB/s]
#
# model.safetensors:  82% 1.81G/2.20G [00:40<00:07, 51.0MB/s]
#
# model.safetensors:  83% 1.82G/2.20G [00:41<00:08, 44.7MB/s]
#
# model.safetensors:  84% 1.85G/2.20G [00:41<00:07, 48.4MB/s]
#
# model.safetensors:  84% 1.86G/2.20G [00:41<00:06, 54.5MB/s]
#
# model.safetensors:  85% 1.87G/2.20G [00:41<00:06, 52.0MB/s]
#
# model.safetensors:  85% 1.88G/2.20G [00:42<00:07, 41.4MB/s]
#
# model.safetensors:  86% 1.90G/2.20G [00:42<00:06, 43.6MB/s]
#
# model.safetensors:  87% 1.91G/2.20G [00:43<00:08, 35.6MB/s]
#
# model.safetensors:  88% 1.93G/2.20G [00:43<00:06, 44.6MB/s]
#
# model.safetensors:  88% 1.94G/2.20G [00:43<00:06, 39.9MB/s]
#
# model.safetensors:  89% 1.96G/2.20G [00:44<00:05, 42.9MB/s]
#
# model.safetensors:  90% 1.97G/2.20G [00:44<00:06, 33.8MB/s]
#
# model.safetensors:  91% 1.99G/2.20G [00:45<00:05, 38.8MB/s]
#
# model.safetensors:  91% 2.00G/2.20G [00:45<00:05, 37.2MB/s]
#
# model.safetensors:  92% 2.02G/2.20G [00:45<00:04, 42.6MB/s]
#
# model.safetensors:  92% 2.03G/2.20G [00:46<00:04, 40.6MB/s]
#
# model.safetensors:  93% 2.06G/2.20G [00:46<00:03, 46.1MB/s]
#
# model.safetensors:  94% 2.07G/2.20G [00:46<00:02, 48.0MB/s]
#
# model.safetensors:  95% 2.09G/2.20G [00:47<00:02, 52.6MB/s]
#
# model.safetensors:  95% 2.10G/2.20G [00:47<00:02, 46.5MB/s]
#
# model.safetensors:  96% 2.12G/2.20G [00:47<00:01, 50.1MB/s]
#
# model.safetensors:  97% 2.13G/2.20G [00:47<00:01, 45.7MB/s]
#
# model.safetensors:  98% 2.15G/2.20G [00:48<00:00, 57.5MB/s]
#
# model.safetensors:  98% 2.16G/2.20G [00:48<00:00, 41.6MB/s]
#
# model.safetensors:  99% 2.18G/2.20G [00:49<00:00, 42.5MB/s]
#
# model.safetensors: 100% 2.19G/2.20G [00:49<00:00, 37.3MB/s]
#
# model.safetensors: 100% 2.20G/2.20G [00:49<00:00, 44.1MB/s]
#
# Fetching 7 files: 100% 7/7 [00:50<00:00,  7.19s/it]
# Warm up loaders: 100% 5/5 [03:16<00:00, 39.36s/it]
# Fetching 8 files: 100% 8/8 [00:00<00:00, 6825.56it/s]
# expert prompts: 100% 4/4 [00:01<00:00,  2.80it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/822M [00:00<?, ?B/s]
# Upload 5 LFS files:   0%|          | 0/5 [00:00<?, ?it/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Abhaykoul/4x1b/commit/f1943f5f8101a75b39cb319d5b1ac5a593835fa4', commit_message='Upload folder using huggingface_hub', commit_description='', oid='f1943f5f8101a75b39cb319d5b1ac5a593835fa4', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # Configs

# %% [markdown]
# Mixture of experts
# ```yml
# base_model: OEvortex/HelpingAI-Lite
# dtype: float16
# gate_mode: cheap_embed
# experts:
#   - source_model: OEvortex/HelpingAI-unvelite
#     positive_prompts: ["You are an helpful unbounded, uncensored assistant."]
#   - source_model: OEvortex/lite-hermes
#     positive_prompts: ["You are helpful assistant."]
#   - source_model: OEvortex/HelpingAI-Lite
#     positive_prompts: ["You are a coding assistant."]
#   - source_model: OEvortex/HelpingAI-Lite-1.5T
#     positive_prompts: ["You are helpful and general-purpose assistant."]
#
# ```

# %% [markdown]
# Merge slerp
# ```yml
# slices:
#   - sources:
#       - model: psmathur/orca_mini_v3_13b
#         layer_range: [0, 40]
#       - model: garage-bAInd/Platypus2-13B
#         layer_range: [0, 40]
# # or, the equivalent models: syntax:
# # models:
# #   - model: psmathur/orca_mini_v3_13b
# #   - model: garage-bAInd/Platypus2-13B
# merge_method: slerp
# base_model: psmathur/orca_mini_v3_13b
# parameters:
#   t:
#     - filter: self_attn
#       value: [0, 0.5, 0.3, 0.7, 1]
#     - filter: mlp
#       value: [1, 0.5, 0.7, 0.3, 0]
#     - value: 0.5 # fallback for rest of tensors
# dtype: float16
# ```

# %% [markdown]
# merge passthrough
# ```yml
# dtype: float16
# merge_method: passthrough
# slices:
# - sources:
#   - layer_range: [0, 8]
#     model: mistralai/Mistral-7B-Instruct-v0.2
# - sources:
#   - layer_range: [4, 12]
#     model: mistralai/Mistral-7B-Instruct-v0.2
# - sources:
#   - layer_range: [8, 16]
#     model: mistralai/Mistral-7B-Instruct-v0.2
# - sources:
#   - layer_range: [12, 20]
#     model: mistralai/Mistral-7B-Instruct-v0.2
# - sources:
#   - layer_range: [16, 24]
#     model: mistralai/Mistral-7B-Instruct-v0.2
# - sources:
#   - layer_range: [20, 28]
#     model: mistralai/Mistral-7B-Instruct-v0.2
# ```

# %% [markdown]
# Merge linear
# ```yml
# models:
#   - model: psmathur/orca_mini_v3_13b
#     parameters:
#       weight: 1.0
#   - model: WizardLM/WizardLM-13B-V1.2
#     parameters:
#       weight: 0.3
#   - model: garage-bAInd/Platypus2-13B
#     parameters:
#       weight: 0.5
# merge_method: linear
# dtype: float16
# ```

# %% [markdown]
# merge ties
# ```yml
# models:
#   - model: psmathur/orca_mini_v3_13b
#     parameters:
#       density: [1, 0.7, 0.1] # density gradient
#       weight: 1.0
#   - model: garage-bAInd/Platypus2-13B
#     parameters:
#       density: 0.5
#       weight: [0, 0.3, 0.7, 1] # weight gradient
#   - model: WizardLM/WizardMath-13B-V1.0
#     parameters:
#       density: 0.33
#       weight:
#         - filter: mlp
#           value: 0.5
#         - value: 0
# merge_method: ties
# base_model: TheBloke/Llama-2-13B-fp16
# parameters:
#   normalize: true
#   int8_mask: true
# dtype: float16
# ```
